# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559700 sha256=072342b238ee67bf405d7702f8a8ec93aebc29e4ddc53aa3d7c09c9d8f9f55df
#   Stored in directory: /Users/akinolusuyi/Library/Caches/pip/wheels/6d/df/5e/ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# WARNING: Error parsing requirements for pyspark: [Errno 2] No such file or directory: '/Users/akinolusuyi/opt/anaconda3/lib/python3.8/site-packages/pyspark-3.2.1.dist-info/METADATA'
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add thelatitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description                          
                          })
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | clyde river
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | dukat
# Processing Record 10 of Set 1 | buala
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | leninskoye
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | cabedelo
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | rostovka
# Processing Record 20 of Set 1 | cockburn town
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | aklavik
# Processing Record 26 of Set 1 | anloga
# Processing Record 27 of Set 1 | ponta delgada
# Processing Record 28 of Set 1 | beloha
# Processing Record 29 of Set 1 | haimen
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | buea
# Processing Record 32 of Set 1 | tura
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | kavaratti
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | oranjemund
# Processing Record 38 of Set 1 | presidencia roque saenz pena
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | mount gambier
# Processing Record 41 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | ketchikan
# Processing Record 47 of Set 1 | sorland
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | pevek
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | bonavista
# Processing Record 5 of Set 2 | wakkanai
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | leningradskiy
# Processing Record 8 of Set 2 | verkhnevilyuysk
# Processing Record 9 of Set 2 | ambovombe
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | quirinopolis
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | kemi
# Processing Record 17 of Set 2 | dahod
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | oistins
# Processing Record 20 of Set 2 | enkoping
# Processing Record 21 of Set 2 | leh
# Processing Record 22 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | mitsamiouli
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | tiznit
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | los llanos de aridane
# Processing Record 30 of Set 2 | phuket
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | rabat
# Processing Record 34 of Set 2 | mbini
# Processing Record 35 of Set 2 | logan lake
# Processing Record 36 of Set 2 | impfondo
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | puerto del rosario
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | gonbad-e qabus
# Processing Record 44 of Set 2 | vao
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | kerema
# Processing Record 47 of Set 2 | camacha
# Processing Record 48 of Set 2 | qidong
# Processing Record 49 of Set 2 | gat
# Processing Record 50 of Set 2 | geraldton
# Processing Record 1 of Set 3 | guerrero negro
# Processing Record 2 of Set 3 | buchanan
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | laguna
# Processing Record 5 of Set 3 | slave lake
# Processing Record 6 of Set 3 | sabana abajo
# City not found. Skipping...
# Processing Record 7 of Set 3 | mataura
# Processing Record 8 of Set 3 | vostok
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | coquimbo
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | cowansville
# Processing Record 13 of Set 3 | santa catarina
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | avanigadda
# Processing Record 16 of Set 3 | sao felix do xingu
# Processing Record 17 of Set 3 | avera
# Processing Record 18 of Set 3 | filadelfia
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | hambantota
# Processing Record 22 of Set 3 | bathsheba
# Processing Record 23 of Set 3 | beringovskiy
# Processing Record 24 of Set 3 | ipixuna
# Processing Record 25 of Set 3 | erenhot
# Processing Record 26 of Set 3 | prince george
# Processing Record 27 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 28 of Set 3 | newark
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | saint-leu
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 3 | la grande
# Processing Record 35 of Set 3 | ulladulla
# Processing Record 36 of Set 3 | pospelikha
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | la union
# Processing Record 39 of Set 3 | sur
# Processing Record 40 of Set 3 | kualakapuas
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 3 | mandali
# Processing Record 46 of Set 3 | yurga
# Processing Record 47 of Set 3 | nome
# Processing Record 48 of Set 3 | tautira
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | kayiry
# Processing Record 2 of Set 4 | sucha beskidzka
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | montana
# Processing Record 6 of Set 4 | asau
# Processing Record 7 of Set 4 | plavinas
# Processing Record 8 of Set 4 | tulum
# Processing Record 9 of Set 4 | zhenlai
# Processing Record 10 of Set 4 | noumea
# Processing Record 11 of Set 4 | alugan
# Processing Record 12 of Set 4 | adrar
# Processing Record 13 of Set 4 | yamada
# Processing Record 14 of Set 4 | beyneu
# Processing Record 15 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 16 of Set 4 | vaitape
# Processing Record 17 of Set 4 | ust-kuyga
# Processing Record 18 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 4 | bengkulu
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | pafos
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | micheweni
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | olbia
# Processing Record 26 of Set 4 | sistranda
# Processing Record 27 of Set 4 | chak jhumra
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | yar-sale
# Processing Record 30 of Set 4 | lake havasu city
# Processing Record 31 of Set 4 | matagami
# Processing Record 32 of Set 4 | samarai
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | carauari
# Processing Record 35 of Set 4 | robertsport
# Processing Record 36 of Set 4 | jamestown
# Processing Record 37 of Set 4 | ahipara
# Processing Record 38 of Set 4 | san ignacio
# Processing Record 39 of Set 4 | yumen
# Processing Record 40 of Set 4 | poum
# Processing Record 41 of Set 4 | tveit
# Processing Record 42 of Set 4 | shumskiy
# Processing Record 43 of Set 4 | staryy nadym
# Processing Record 44 of Set 4 | chumikan
# Processing Record 45 of Set 4 | riyadh
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | springbok
# Processing Record 48 of Set 4 | barrow
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | andrelandia
# Processing Record 2 of Set 5 | elat
# Processing Record 3 of Set 5 | coahuayana
# Processing Record 4 of Set 5 | hobart
# Processing Record 5 of Set 5 | ayacucho
# Processing Record 6 of Set 5 | colac
# Processing Record 7 of Set 5 | sao paulo de olivenca
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | xunchang
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 5 | taoudenni
# Processing Record 13 of Set 5 | maumere
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | payo
# Processing Record 16 of Set 5 | praia
# Processing Record 17 of Set 5 | mehamn
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | asosa
# Processing Record 20 of Set 5 | hohen neuendorf
# Processing Record 21 of Set 5 | russell
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | port-cartier
# Processing Record 24 of Set 5 | buinsk
# Processing Record 25 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 5 | punta cardon
# Processing Record 27 of Set 5 | maluso
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | callosa de segura
# Processing Record 30 of Set 5 | emba
# Processing Record 31 of Set 5 | usinsk
# Processing Record 32 of Set 5 | khuzhir
# Processing Record 33 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 5 | sterling
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | lata
# Processing Record 37 of Set 5 | ambikapur
# Processing Record 38 of Set 5 | saint-philippe
# Processing Record 39 of Set 5 | cairns
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | broome
# Processing Record 43 of Set 5 | akureyri
# Processing Record 44 of Set 5 | ponta do sol
# Processing Record 45 of Set 5 | faanui
# Processing Record 46 of Set 5 | anadyr
# Processing Record 47 of Set 5 | port elizabeth
# Processing Record 48 of Set 5 | beaufort
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | novyy urengoy
# Processing Record 1 of Set 6 | lagoa
# Processing Record 2 of Set 6 | te anau
# Processing Record 3 of Set 6 | campina verde
# Processing Record 4 of Set 6 | akonolinga
# Processing Record 5 of Set 6 | klaksvik
# Processing Record 6 of Set 6 | correggio
# Processing Record 7 of Set 6 | saint anthony
# Processing Record 8 of Set 6 | sussex
# Processing Record 9 of Set 6 | baruun-urt
# Processing Record 10 of Set 6 | kabin buri
# Processing Record 11 of Set 6 | narsaq
# Processing Record 12 of Set 6 | airai
# Processing Record 13 of Set 6 | acapulco
# Processing Record 14 of Set 6 | horsham
# Processing Record 15 of Set 6 | banfora
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | virginia beach
# Processing Record 18 of Set 6 | thaton
# Processing Record 19 of Set 6 | malanje
# Processing Record 20 of Set 6 | severo-kurilsk
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | hammerfest
# Processing Record 23 of Set 6 | tynda
# Processing Record 24 of Set 6 | college
# Processing Record 25 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 6 | zhangye
# Processing Record 27 of Set 6 | cayenne
# Processing Record 28 of Set 6 | arroyo
# Processing Record 29 of Set 6 | bismarck
# Processing Record 30 of Set 6 | sakakah
# Processing Record 31 of Set 6 | east london
# Processing Record 32 of Set 6 | soyaux
# Processing Record 33 of Set 6 | havelock
# Processing Record 34 of Set 6 | griffith
# Processing Record 35 of Set 6 | christchurch
# Processing Record 36 of Set 6 | bonnyville
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | chaman
# Processing Record 39 of Set 6 | naryan-mar
# Processing Record 40 of Set 6 | fare
# Processing Record 41 of Set 6 | inhambane
# Processing Record 42 of Set 6 | kadoma
# Processing Record 43 of Set 6 | ilulissat
# Processing Record 44 of Set 6 | chokurdakh
# Processing Record 45 of Set 6 | lompoc
# Processing Record 46 of Set 6 | ust-koksa
# Processing Record 47 of Set 6 | buritis
# Processing Record 48 of Set 6 | kantunilkin
# Processing Record 49 of Set 6 | misratah
# Processing Record 50 of Set 6 | kieta
# Processing Record 1 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 7 | ormara
# Processing Record 3 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 4 of Set 7 | nemuro
# Processing Record 5 of Set 7 | inverness
# Processing Record 6 of Set 7 | koslan
# Processing Record 7 of Set 7 | camaqua
# Processing Record 8 of Set 7 | magadan
# Processing Record 9 of Set 7 | albert town
# Processing Record 10 of Set 7 | cabo san lucas
# Processing Record 11 of Set 7 | santo antonio do ica
# Processing Record 12 of Set 7 | datong
# Processing Record 13 of Set 7 | conceicao do araguaia
# Processing Record 14 of Set 7 | lavrentiya
# Processing Record 15 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 7 | trinidad
# Processing Record 17 of Set 7 | cidreira
# Processing Record 18 of Set 7 | san cristobal
# Processing Record 19 of Set 7 | salinopolis
# Processing Record 20 of Set 7 | amazar
# Processing Record 21 of Set 7 | sechura
# Processing Record 22 of Set 7 | yerbogachen
# Processing Record 23 of Set 7 | commerce
# Processing Record 24 of Set 7 | takoradi
# Processing Record 25 of Set 7 | torbay
# Processing Record 26 of Set 7 | mala
# Processing Record 27 of Set 7 | realeza
# Processing Record 28 of Set 7 | shingu
# Processing Record 29 of Set 7 | sept-iles
# Processing Record 30 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 31 of Set 7 | luwuk
# Processing Record 32 of Set 7 | ponferrada
# Processing Record 33 of Set 7 | el prat de llobregat
# Processing Record 34 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 7 | bambous virieux
# Processing Record 36 of Set 7 | prince rupert
# Processing Record 37 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 38 of Set 7 | chifeng
# Processing Record 39 of Set 7 | valdivia
# Processing Record 40 of Set 7 | sioux lookout
# Processing Record 41 of Set 7 | manta
# Processing Record 42 of Set 7 | qurbah
# City not found. Skipping...
# Processing Record 43 of Set 7 | kurumkan
# Processing Record 44 of Set 7 | suntar
# Processing Record 45 of Set 7 | soyo
# Processing Record 46 of Set 7 | chapleau
# Processing Record 47 of Set 7 | monte alegre
# Processing Record 48 of Set 7 | kolondieba
# Processing Record 49 of Set 7 | rovaniemi
# Processing Record 50 of Set 7 | berlevag
# Processing Record 1 of Set 8 | staicele
# Processing Record 2 of Set 8 | manggar
# Processing Record 3 of Set 8 | cerrito
# Processing Record 4 of Set 8 | kenitra
# Processing Record 5 of Set 8 | dori
# Processing Record 6 of Set 8 | halifax
# Processing Record 7 of Set 8 | concepcion
# Processing Record 8 of Set 8 | moranbah
# Processing Record 9 of Set 8 | teguise
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | marsabit
# Processing Record 12 of Set 8 | angoche
# Processing Record 13 of Set 8 | padang
# Processing Record 14 of Set 8 | nagato
# Processing Record 15 of Set 8 | saiki
# Processing Record 16 of Set 8 | manicore
# Processing Record 17 of Set 8 | irtyshskiy
# Processing Record 18 of Set 8 | mackay
# Processing Record 19 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 8 | sinnamary
# Processing Record 21 of Set 8 | banamba
# Processing Record 22 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 23 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 24 of Set 8 | tutoia
# Processing Record 25 of Set 8 | martapura
# Processing Record 26 of Set 8 | khomeynishahr
# City not found. Skipping...
# Processing Record 27 of Set 8 | sao filipe
# Processing Record 28 of Set 8 | nishihara
# Processing Record 29 of Set 8 | manavgat
# Processing Record 30 of Set 8 | sertaozinho
# Processing Record 31 of Set 8 | mayo
# Processing Record 32 of Set 8 | urubamba
# Processing Record 33 of Set 8 | odienne
# Processing Record 34 of Set 8 | kodiak
# Processing Record 35 of Set 8 | eirunepe
# Processing Record 36 of Set 8 | chaa-khol
# City not found. Skipping...
# Processing Record 37 of Set 8 | matara
# Processing Record 38 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | rimini
# Processing Record 40 of Set 8 | port-gentil
# Processing Record 41 of Set 8 | reconquista
# Processing Record 42 of Set 8 | oxbow
# Processing Record 43 of Set 8 | kijang
# Processing Record 44 of Set 8 | xuddur
# Processing Record 45 of Set 8 | mushie
# Processing Record 46 of Set 8 | canavieiras
# Processing Record 47 of Set 8 | cam ranh
# Processing Record 48 of Set 8 | rawa mazowiecka
# Processing Record 49 of Set 8 | timmins
# Processing Record 50 of Set 8 | warrington
# Processing Record 1 of Set 9 | ambatondrazaka
# Processing Record 2 of Set 9 | pandamatenga
# Processing Record 3 of Set 9 | plon
# Processing Record 4 of Set 9 | abnub
# Processing Record 5 of Set 9 | velsk
# Processing Record 6 of Set 9 | teofilo otoni
# Processing Record 7 of Set 9 | sombrerete
# Processing Record 8 of Set 9 | polunochnoye
# Processing Record 9 of Set 9 | nehe
# Processing Record 10 of Set 9 | oktyabrskoye
# Processing Record 11 of Set 9 | cumaru
# Processing Record 12 of Set 9 | pouebo
# Processing Record 13 of Set 9 | mount isa
# Processing Record 14 of Set 9 | nhulunbuy
# Processing Record 15 of Set 9 | puerto penasco
# Processing Record 16 of Set 9 | kichera
# Processing Record 17 of Set 9 | vila
# Processing Record 18 of Set 9 | tammisaari
# Processing Record 19 of Set 9 | awjilah
# Processing Record 20 of Set 9 | batemans bay
# Processing Record 21 of Set 9 | dharchula
# Processing Record 22 of Set 9 | amberley
# Processing Record 23 of Set 9 | tres de maio
# Processing Record 24 of Set 9 | kenora
# Processing Record 25 of Set 9 | yatou
# Processing Record 26 of Set 9 | pochutla
# Processing Record 27 of Set 9 | chandia
# Processing Record 28 of Set 9 | tamale
# Processing Record 29 of Set 9 | talcahuano
# Processing Record 30 of Set 9 | isangel
# Processing Record 31 of Set 9 | sobolevo
# Processing Record 32 of Set 9 | kamaishi
# Processing Record 33 of Set 9 | yambio
# Processing Record 34 of Set 9 | villa carlos paz
# Processing Record 35 of Set 9 | alice springs
# Processing Record 36 of Set 9 | catuday
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | lorengau
# Processing Record 39 of Set 9 | abapo
# Processing Record 40 of Set 9 | nyrob
# Processing Record 41 of Set 9 | praia da vitoria
# Processing Record 42 of Set 9 | maniitsoq
# Processing Record 43 of Set 9 | pangnirtung
# Processing Record 44 of Set 9 | waipawa
# Processing Record 45 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 9 | imbituba
# Processing Record 47 of Set 9 | saint-joseph
# Processing Record 48 of Set 9 | tumpat
# Processing Record 49 of Set 9 | puerto pinasco
# City not found. Skipping...
# Processing Record 50 of Set 9 | obo
# Processing Record 1 of Set 10 | kleive
# Processing Record 2 of Set 10 | deputatskiy
# Processing Record 3 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 10 | labuhan
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | zinapecuaro
# Processing Record 7 of Set 10 | mareeba
# Processing Record 8 of Set 10 | svetlaya
# Processing Record 9 of Set 10 | pacific grove
# Processing Record 10 of Set 10 | henties bay
# Processing Record 11 of Set 10 | seoul
# Processing Record 12 of Set 10 | japura
# Processing Record 13 of Set 10 | palmer
# Processing Record 14 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 10 | prachuap khiri khan
# Processing Record 16 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 10 | nizwa
# Processing Record 18 of Set 10 | lima
# Processing Record 19 of Set 10 | bandarbeyla
# Processing Record 20 of Set 10 | yanam
# Processing Record 21 of Set 10 | katherine
# Processing Record 22 of Set 10 | puerto colombia
# Processing Record 23 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 10 | doha
# Processing Record 25 of Set 10 | tarakan
# Processing Record 26 of Set 10 | baracoa
# Processing Record 27 of Set 10 | beni
# Processing Record 28 of Set 10 | kokologo
# Processing Record 29 of Set 10 | payyannur
# Processing Record 30 of Set 10 | mirina
# City not found. Skipping...
# Processing Record 31 of Set 10 | rawson
# Processing Record 32 of Set 10 | daryapur
# Processing Record 33 of Set 10 | kaitangata
# Processing Record 34 of Set 10 | asyut
# Processing Record 35 of Set 10 | evensk
# Processing Record 36 of Set 10 | puerto escondido
# Processing Record 37 of Set 10 | roches noires
# City not found. Skipping...
# Processing Record 38 of Set 10 | shimoda
# Processing Record 39 of Set 10 | flinders
# Processing Record 40 of Set 10 | aksu
# Processing Record 41 of Set 10 | bom jesus
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | matamoros
# Processing Record 44 of Set 10 | andenes
# Processing Record 45 of Set 10 | eureka
# Processing Record 46 of Set 10 | toamasina
# Processing Record 47 of Set 10 | korem
# Processing Record 48 of Set 10 | lincoln
# Processing Record 49 of Set 10 | qaqortoq
# Processing Record 50 of Set 10 | hamina
# Processing Record 1 of Set 11 | morgan city
# Processing Record 2 of Set 11 | pisco
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | dubbo
# Processing Record 5 of Set 11 | pangai
# Processing Record 6 of Set 11 | soverato
# Processing Record 7 of Set 11 | acarau
# Processing Record 8 of Set 11 | katsuura
# Processing Record 9 of Set 11 | guasdualito
# Processing Record 10 of Set 11 | finote selam
# Processing Record 11 of Set 11 | half moon bay
# Processing Record 12 of Set 11 | dogondoutchi
# Processing Record 13 of Set 11 | mananjary
# Processing Record 14 of Set 11 | eraniel
# Processing Record 15 of Set 11 | aransas pass
# Processing Record 16 of Set 11 | bemidji
# Processing Record 17 of Set 11 | soubre
# Processing Record 18 of Set 11 | pervomayskoye
# Processing Record 19 of Set 11 | balkhash
# Processing Record 20 of Set 11 | xifeng
# Processing Record 21 of Set 11 | itaituba
# Processing Record 22 of Set 11 | san carlos de bariloche
# Processing Record 23 of Set 11 | horana
# Processing Record 24 of Set 11 | hobyo
# Processing Record 25 of Set 11 | ambilobe
# Processing Record 26 of Set 11 | da nang
# Processing Record 27 of Set 11 | roros
# Processing Record 28 of Set 11 | la cruz
# Processing Record 29 of Set 11 | razdolinsk
# Processing Record 30 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 11 | nuuk
# Processing Record 32 of Set 11 | saint-raymond
# Processing Record 33 of Set 11 | araouane
# Processing Record 34 of Set 11 | flin flon
# Processing Record 35 of Set 11 | phonhong
# Processing Record 36 of Set 11 | port hedland
# Processing Record 37 of Set 11 | santa cruz
# Processing Record 38 of Set 11 | dengzhou
# Processing Record 39 of Set 11 | jiaozuo
# Processing Record 40 of Set 11 | vilhena
# Processing Record 41 of Set 11 | cervo
# Processing Record 42 of Set 11 | biltine
# Processing Record 43 of Set 11 | wattegama
# Processing Record 44 of Set 11 | inuvik
# Processing Record 45 of Set 11 | kirovskiy
# Processing Record 46 of Set 11 | beeville
# Processing Record 47 of Set 11 | san isidro
# Processing Record 48 of Set 11 | tual
# Processing Record 49 of Set 11 | aljezur
# Processing Record 50 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 12 | vardo
# Processing Record 2 of Set 12 | gigmoto
# Processing Record 3 of Set 12 | yarada
# Processing Record 4 of Set 12 | grand-lahou
# Processing Record 5 of Set 12 | elk point
# Processing Record 6 of Set 12 | puerto el triunfo
# Processing Record 7 of Set 12 | coxim
# Processing Record 8 of Set 12 | chapayevka
# Processing Record 9 of Set 12 | kinango
# Processing Record 10 of Set 12 | saldanha
# Processing Record 11 of Set 12 | onokhoy
# Processing Record 12 of Set 12 | saravena
# Processing Record 13 of Set 12 | strezhevoy
# Processing Record 14 of Set 12 | gorontalo
# Processing Record 15 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 12 | tezu
# Processing Record 17 of Set 12 | walvis bay
# Processing Record 18 of Set 12 | dalbandin
# Processing Record 19 of Set 12 | anaconda
# Processing Record 20 of Set 12 | aripuana
# Processing Record 21 of Set 12 | grand gaube
# Processing Record 22 of Set 12 | madang
# Processing Record 23 of Set 12 | aksarka
# Processing Record 24 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 12 | jawhar
# Processing Record 26 of Set 12 | san andres
# Processing Record 27 of Set 12 | vestmannaeyjar
# Processing Record 28 of Set 12 | ravar
# Processing Record 29 of Set 12 | council bluffs
# Processing Record 30 of Set 12 | estelle
# Processing Record 31 of Set 12 | karhal
# Processing Record 32 of Set 12 | pirmasens
# Processing Record 33 of Set 12 | marsh harbour
# Processing Record 34 of Set 12 | benghazi
# Processing Record 35 of Set 12 | straseni
# Processing Record 36 of Set 12 | pandan
# Processing Record 37 of Set 12 | chulakivka
# Processing Record 38 of Set 12 | poplar bluff
# Processing Record 39 of Set 12 | vlakhoyiannion
# City not found. Skipping...
# Processing Record 40 of Set 12 | oinoussai
# City not found. Skipping...
# Processing Record 41 of Set 12 | banjar
# Processing Record 42 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 12 | pringsewu
# Processing Record 44 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 12 | san fernando
# Processing Record 46 of Set 12 | aviles
# Processing Record 47 of Set 12 | marzuq
# Processing Record 48 of Set 12 | whitehorse
# Processing Record 49 of Set 12 | nauta
# Processing Record 50 of Set 12 | esil
# Processing Record 1 of Set 13 | stepnyak
# Processing Record 2 of Set 13 | banda aceh
# Processing Record 3 of Set 13 | panama city
# Processing Record 4 of Set 13 | mpanda
# Processing Record 5 of Set 13 | nguru
# Processing Record 6 of Set 13 | pedasi
# Processing Record 7 of Set 13 | hecun
# Processing Record 8 of Set 13 | jijiga
# Processing Record 9 of Set 13 | kawalu
# Processing Record 10 of Set 13 | krasnokamensk
# Processing Record 11 of Set 13 | bahia honda
# Processing Record 12 of Set 13 | san gavino monreale
# Processing Record 13 of Set 13 | thongwa
# Processing Record 14 of Set 13 | labrea
# Processing Record 15 of Set 13 | axim
# Processing Record 16 of Set 13 | kasama
# Processing Record 17 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 13 | touros
# Processing Record 19 of Set 13 | santa maria
# Processing Record 20 of Set 13 | yefimovskiy
# City not found. Skipping...
# Processing Record 21 of Set 13 | mandalgovi
# Processing Record 22 of Set 13 | bisira
# Processing Record 23 of Set 13 | churapcha
# Processing Record 24 of Set 13 | chapais
# Processing Record 25 of Set 13 | calvia
# Processing Record 26 of Set 13 | sao jose da coroa grande
# Processing Record 27 of Set 13 | shenjiamen
# Processing Record 28 of Set 13 | manaus
# Processing Record 29 of Set 13 | lumeje
# Processing Record 30 of Set 13 | khushab
# Processing Record 31 of Set 13 | vanimo
# Processing Record 32 of Set 13 | shache
# Processing Record 33 of Set 13 | nanortalik
# Processing Record 34 of Set 13 | kasongo-lunda
# Processing Record 35 of Set 13 | swan river
# Processing Record 36 of Set 13 | santa cecilia
# Processing Record 37 of Set 13 | qostanay
# Processing Record 38 of Set 13 | aitape
# Processing Record 39 of Set 13 | yalta
# Processing Record 40 of Set 13 | pathein
# Processing Record 41 of Set 13 | viedma
# Processing Record 42 of Set 13 | sai buri
# Processing Record 43 of Set 13 | novo aripuana
# Processing Record 44 of Set 13 | saint-augustin
# Processing Record 45 of Set 13 | sola
# Processing Record 46 of Set 13 | kitami
# Processing Record 47 of Set 13 | whitecourt
# Processing Record 48 of Set 13 | atar
# Processing Record 49 of Set 13 | manuk mangkaw
# Processing Record 50 of Set 13 | aguimes
# Processing Record 1 of Set 14 | nkhotakota
# Processing Record 2 of Set 14 | emmaus
# Processing Record 3 of Set 14 | ca mau
# Processing Record 4 of Set 14 | san
# Processing Record 5 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 6 of Set 14 | omboue
# Processing Record 7 of Set 14 | lebyazhye
# Processing Record 8 of Set 14 | alyangula
# Processing Record 9 of Set 14 | itoman
# Processing Record 10 of Set 14 | harper
# Processing Record 11 of Set 14 | paramonga
# Processing Record 12 of Set 14 | sao joao da barra
# Processing Record 13 of Set 14 | karatau
# Processing Record 14 of Set 14 | akyab
# Processing Record 15 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 14 | taltal
# Processing Record 17 of Set 14 | gimli
# Processing Record 18 of Set 14 | dombarovskiy
# Processing Record 19 of Set 14 | faya
# Processing Record 20 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 14 | sao mateus do sul
# Processing Record 22 of Set 14 | port augusta
# Processing Record 23 of Set 14 | najran
# Processing Record 24 of Set 14 | kutum
# Processing Record 25 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 26 of Set 14 | bhinga
# Processing Record 27 of Set 14 | bouca
# Processing Record 28 of Set 14 | codrington
# Processing Record 29 of Set 14 | bardsir
# Processing Record 30 of Set 14 | maceio
# Processing Record 31 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 32 of Set 14 | ostrovnoy
# Processing Record 33 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 34 of Set 14 | timoteo
# Processing Record 35 of Set 14 | treinta y tres
# Processing Record 36 of Set 14 | xichang
# Processing Record 37 of Set 14 | kununurra
# Processing Record 38 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 39 of Set 14 | les cayes
# Processing Record 40 of Set 14 | cumra
# Processing Record 41 of Set 14 | shellbrook
# Processing Record 42 of Set 14 | maningrida
# Processing Record 43 of Set 14 | isla vista
# Processing Record 44 of Set 14 | olga
# Processing Record 45 of Set 14 | anahuac
# Processing Record 46 of Set 14 | moratuwa
# Processing Record 47 of Set 14 | salme
# Processing Record 48 of Set 14 | kamen-na-obi
# Processing Record 49 of Set 14 | kungurtug
# Processing Record 50 of Set 14 | gamba
# Processing Record 1 of Set 15 | scarborough
# Processing Record 2 of Set 15 | kourou
# Processing Record 3 of Set 15 | roald
# Processing Record 4 of Set 15 | kambove
# Processing Record 5 of Set 15 | ewa beach
# Processing Record 6 of Set 15 | miranda de ebro
# Processing Record 7 of Set 15 | haines junction
# Processing Record 8 of Set 15 | rundu
# Processing Record 9 of Set 15 | robore
# Processing Record 10 of Set 15 | tobol
# Processing Record 11 of Set 15 | basco
# Processing Record 12 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 15 | amapa
# Processing Record 14 of Set 15 | lahad datu
# Processing Record 15 of Set 15 | bubaque
# Processing Record 16 of Set 15 | dabakala
# Processing Record 17 of Set 15 | gubkinskiy
# Processing Record 18 of Set 15 | sayyan
# Processing Record 19 of Set 15 | tunceli
# Processing Record 20 of Set 15 | honiara
# Processing Record 21 of Set 15 | glendive
# Processing Record 22 of Set 15 | kaeo
# Processing Record 23 of Set 15 | calvinia
# Processing Record 24 of Set 15 | bacungan
# Processing Record 25 of Set 15 | tuy hoa
# Processing Record 26 of Set 15 | mahibadhoo
# Processing Record 27 of Set 15 | karmala
# Processing Record 28 of Set 15 | wolgast
# Processing Record 29 of Set 15 | high level
# Processing Record 30 of Set 15 | paamiut
# Processing Record 31 of Set 15 | todos santos
# Processing Record 32 of Set 15 | saint albans
# Processing Record 33 of Set 15 | pittsfield
# Processing Record 34 of Set 15 | porto novo
# Processing Record 35 of Set 15 | olimpia
# Processing Record 36 of Set 15 | bogatoye
# Processing Record 37 of Set 15 | myitkyina
# Processing Record 38 of Set 15 | skjervoy
# Processing Record 39 of Set 15 | imbituva
# Processing Record 40 of Set 15 | male
# Processing Record 41 of Set 15 | pirai do sul
# Processing Record 42 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 15 | smithers
# Processing Record 45 of Set 15 | pangkalanbuun
# Processing Record 46 of Set 15 | grahamstown
# Processing Record 47 of Set 15 | ocampo
# Processing Record 48 of Set 15 | port blair
# Processing Record 49 of Set 15 | vinh
# Processing Record 50 of Set 15 | kalabo
# Processing Record 1 of Set 16 | rocha
# Processing Record 2 of Set 16 | keetmanshoop
# Processing Record 3 of Set 16 | nettuno
# Processing Record 4 of Set 16 | richards bay
# Processing Record 5 of Set 16 | ritchie
# Processing Record 6 of Set 16 | albox
# Processing Record 7 of Set 16 | norilsk
# Processing Record 8 of Set 16 | fayaoue
# Processing Record 9 of Set 16 | aswan
# Processing Record 10 of Set 16 | ha tinh
# Processing Record 11 of Set 16 | krasnovishersk
# Processing Record 12 of Set 16 | barda
# Processing Record 13 of Set 16 | tanabe
# Processing Record 14 of Set 16 | mount pleasant
# Processing Record 15 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 16 | north branch
# Processing Record 17 of Set 16 | elko
# Processing Record 18 of Set 16 | kalmunai
# Processing Record 19 of Set 16 | sorong
# Processing Record 20 of Set 16 | ginir
# Processing Record 21 of Set 16 | mahon
# Processing Record 22 of Set 16 | okahandja
# Processing Record 23 of Set 16 | makakilo city
# Processing Record 24 of Set 16 | bratsk
# Processing Record 25 of Set 16 | garowe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Kruisfontein      ZA -34.0033   24.7314     59.88        87         100
# 1    Butaritari      KI   3.0707  172.7902     80.69        70          38
# 2  Punta Arenas      CL -53.1500  -70.9167     48.31        71           0
# 3   Clyde River      CA  70.4692  -68.5914     -3.77        77         100
# 4      Zhigansk      RU  66.7697  123.3711     10.67        84          49
# 5   New Norfolk      AU -42.7826  147.0587     72.91        42          53
# 6         Bluff      NZ -46.6000  168.3333     60.39        74          18
# 7         Dukat      RU  62.5500  155.5500      9.57        84         100
# 8         Buala      SB  -8.1450  159.5921     83.44        75          77
# 9    Bredasdorp      ZA -34.5322   20.0403     62.62        64         100
#
#    Wind Speed       Description
# 0       12.08     moderate rain
# 1       12.15  scattered clouds
# 2       16.11         clear sky
# 3       24.16        light snow
# 4        5.48  scattered clouds
# 5        4.00     broken clouds
# 6        9.40        few clouds
# 7        3.96   overcast clouds
# 8        3.18        light rain
# 9       12.82   overcast clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv",index_label="City_ID")
